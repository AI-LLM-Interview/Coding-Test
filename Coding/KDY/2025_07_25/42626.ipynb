# %% [markdown]
# # 더 맵게

# %%
import heapq

def solution(scoville, k):
    answer = 0
    heapq.heapify(scoville)
    # scoville.sort()
    # x = heapq.heappop(scoville)
    # if len(scoville) == 1:
    #     if scoville[0] >= k:
    #         return 0
    #     else:
    #         return -1
    # for _ in range(len(scoville)-1):
    
    if all(ss >= k for ss in scoville):
        # if min(scoville) >= k: 
            return answer
        
    while len(scoville) >= 2:
        f = heapq.heappop(scoville)
        s = heapq.heappop(scoville)
        x = f + (s*2)
        # print(f,s,x)
        heapq.heappush(scoville,x)
        
        answer += 1
        # print(scoville)
        
        if all(ss >= k for ss in scoville):
        # if min(scoville) >= k: 
            return answer
        
    return -1
    # return answer if scoville[0] >= k else -1

# %%
# test
print(solution([1, 2, 3, 9, 10, 12], 7))  

# Expected output: 2
# Out:
# 2
