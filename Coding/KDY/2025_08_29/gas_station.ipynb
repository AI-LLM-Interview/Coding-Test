# %% [markdown]
# 134. Gas Station
# Attempted
# Medium
# Topics
# premium lock icon
# Companies
# There are n gas stations along a circular route, where the amount of gas at the ith station is gas[i].
#
# You have a car with an unlimited gas tank and it costs cost[i] of gas to travel from the ith station to its next (i + 1)th station. You begin the journey with an empty tank at one of the gas stations.
#
# Given two integer arrays gas and cost, return the starting gas station's index if you can travel around the circuit once in the clockwise direction, otherwise return -1. If there exists a solution, it is guaranteed to be unique.

# %%
# 시간초과

class Solution(object):
    def canCompleteCircuit(self, gas, cost):
        n = len(gas)
        gas += gas
        cost += cost
        lst = []
        for i in range(n):
            tank = gas[i]
            # print('------',gas[i],'------')
            lst.append(i)
            for j in range(n):
                # print('tank',tank, ' cost',cost[i+j], ' gas',gas[i+j+1], ' total', tank-cost[i+j]+gas[i+j+1])
                tank -= cost[i+j]
                if tank <0:
                    lst.pop()
                    break
                tank += gas[i+j+1]
                # if tank <0:
                #     lst.append(-1)
                #     break
                # lst.append(gas[i])
        if not lst:
            return -1
        return lst[0]

# %%
# 위 방식에서 시간 줄임

class Solution(object):
    def canCompleteCircuit(self, gas, cost):
        n = len(gas)
        # 전체 연료가 전체 비용보다 적으면 불가능 (빠른 컷)
        if sum(gas) < sum(cost):
            return -1

        # 원래 코드 흐름 유지: 배열을 두 배로 늘려 선형 순회
        gas = gas * 2
        cost = cost * 2

        i = 0  # 시작 후보
        while i < n:
            tank = 0
            # i에서 시작해 n칸 시도
            for j in range(i, i + n):
                tank += gas[j] - cost[j]
                if tank < 0:
                    # j에서 깨지면 i..j 사이 어떤 시작도 소용없음 → 다음 후보는 j+1
                    i = j + 1
                    break
            else:
                # for가 끝까지 돌았다면 i가 정답
                return i % n

        return -1
