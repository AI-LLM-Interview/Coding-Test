# %% [markdown]
# 아날로그 시계

# %%
def solution(h1, m1, s1, h2, m2, s2):
    answer = -1
    # 초침: 1초 6도
    # 분침: 1초 0.1도
    # 시침: 1초 1/120도
    # 86400
    h=h2-h1
    m=m2-m1
    s=s2-s1
    
    time = h*3600 + m *60 + s
    print(time)
    hh = h1*3600*(1/120)
    mm = m1*60*(0.1)
    ss = s1*6
    print(hh,mm,ss)
    
    for t in range(5):
        hh += (1/120)
        mm += (0.1)
        ss += 6
        print(hh,mm,ss)
        
    # for t in range(time):
    #     hh = h1 + (1/120)*t
    #     mm = m1 + (0.1)*t
    #     ss = s1 + 6*t
    return answer
