# %% [markdown]
# https://school.programmers.co.kr/learn/courses/30/lessons/150367

# %%
def solution(numbers):
    answer = []
    for i in numbers:
        bin_num = format(i, 'b')
        print(bin_num)
        # 이진트리 탐색 추가

    return answer
