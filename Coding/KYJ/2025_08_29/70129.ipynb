# %% [markdown]
# https://school.programmers.co.kr/learn/courses/30/lessons/70129

# %%
def solution(s):
    answer = []
    aa = str(s)
    a = 0
    b = 0
    while aa != '1':
        a += aa.count('0')
        aa = format(aa.count('1'),'b')
        print(aa)
        b += 1
    print(aa.count('0'))
    
    #print(bin(int(aa)))
    #print( format(int(aa.count('1')),2) )
    answer = [b,a]
    
    return answer
